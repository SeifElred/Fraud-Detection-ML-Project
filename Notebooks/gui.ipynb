# %%
import streamlit as st
import pandas as pd
import joblib

# Modeli yükle
model = joblib.load("random_forest_model.pkl")

# Başlık
st.write("Lütfen özellik değerlerini giriniz.")

# Kullanıcıdan giriş verilerini al
input_data = {}

# V1'den V28'e kadar olan veriler için giriş kutuları
for i in range(1, 29):
    feature = f"V{i}"
    input_data[feature] = st.number_input(f"{feature} değerini giriniz:", value=0.0)

# Amount verisi için giriş
input_data['Amount'] = st.number_input("Amount (Miktar) değerini giriniz:", value=0.0)

# Veri çerçevesine dönüştür
input_df = pd.DataFrame([input_data])

# Tahmin yap
if st.button("Tahmin Yap"):
    prediction = model.predict(input_df)
    result = "Dolandırıcılık" if prediction[0] == 1 else "Normal İşlem"
    st.write(f"Tahmin Sonucu: {result}")
# Out:
# 2024-12-21 15:20:38.702 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.797
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/melihcifci/anaconda3/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-12-21 15:20:38.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.798 Session state does not function when running a script without `streamlit run`
# 2024-12-21 15:20:38.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.801 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.804 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.805 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.806 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.807 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.809 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.811 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-12-21 15:20:38.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
